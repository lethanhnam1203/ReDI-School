# %% [markdown]
# # Menti Questions

# %% [markdown]
# ## Question 1:

# %%
# What will this function call return:

def some_funct(a):
  number = 10* a
  return number

print(some_funct(20))
# Out:
# 200

# %%
test = print("Hello")
print(test)
# Out:
# Hello
# None

# %%
def test_no_param():
  print("Hello no param")
test_no_param()
# Out:
# Hello no param

# %%
def greeting_function(name):
  print(f"Hello {name}")

test = greeting_function("Caroline")
print(test)
# Out:
# Hello Caroline
# None

# %%
# What is a correct function definition
# Option 1:
def tester(a)
  return a

# Option 2:
func tester(a):
 return a

# Option 3:
definition tester(a):
 return a

# Option 4:
def tester(a):
  return a
