# %% [markdown]
# # Exercise 1 - FizzBuzz
#
# a) Write a function `fizz_buzz()`that takes a number as parameter
# - if the number is divisible by 3, return `"fizz"`
# - if the number is devisible by 5 return `"buzz"`
# - if it is dvisble by 3 and 5, return `"fizzbuzz"`
# - in all other cases return an empty string
#
#
# *Example*:
# ```python
# fizz_buzz(9) -> "fizz"
# fizz_buzz(10) -> "buzz"
# fizz_buzz(15) -> "fizzbuzz"
# fizz_buzz(16) -> ""
# ```

# %%
def fizz_buzz(number):
    return 0

# %% [markdown]
# b) **Bonus**
# Write a function `first_n_fizz_buzz()` that will accept a number as input and that will print the result of `fizz_buzz` for all numbers between one and the number
#
# *Example:*
#
# ```python
# first_n_fizz_buzz(4)
#   -> 1: FizzBuzz is ""
#      2: FizzBuzz is ""
#      3: FizzBuzz is "fizz"
#      4: FizzBuzz is ""
# ```

# %% [markdown]
# # Exercise 2
# Write a function to charaters in a string to a list of characters. Extracting individual letter from a word.
#
# **For example**
#
# Function get_characters("apple") should return ['a', 'p', 'p', 'l', 'e']
#
# Function get_characters("baloon") should return ['b', 'a', 'l', 'o', 'o', 'n']

# %% [markdown]
# # Exercise 3
# Write a function to find the vowels in a String and return the vowels in a list.
#
# **For example:**
#
# find_vowels("apple") should return the list ['a', 'e']
#
# find_vowels("baloon") should return the list ['a', 'o', 'o']

# %% [markdown]
# # Exercise 4
# Write a function to find unique vowels in a string and return vowels as a list. The function must reuse codes from Exercises 2 and 3.
#
# For example: find_vowels("baloon") should return the list ['a', 'o'] and not ['a', 'o', 'o'] <br>
# Hint: Set vs List

# %% [markdown]
# # Exercise 5
# Build an action hero index.
#
# action_heroes = ["James Bond", "Jason Bourne", "Iron Man", "Super Man", "Thor", "Spiderman"]
#
# 1. Write a function for users to add more character to the list of action heroes. Hint: You can use input function.
# 2. Write a function that allows users to search for characters in the action_heroes list.
#
# **For Example**
#
# get_action_heroes("man") should return a list of ["Iron Man", "Super Man", "Spiderman"]
#
# get_action_heroes("J") should return a list of ["James Bond", "Jason Bourne"]

# %%
action_heroes = ["James Bond", "Jason Bourne", "Iron Man", "Super Man", "Thor", "Spiderman"]

# %% [markdown]
# # Exercise 6
# Write a function that accept users first and last name and returns after replacing all charachters except the initials.
#
# For example: Function mask_username(first_name, last_name)
#
# `mask_username("John", "Doe") returns "J*** D**"`
